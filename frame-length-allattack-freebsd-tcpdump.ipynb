# %%
# !tshark -n -r allatttack_freebsd_tcpdump.pcap -T fields -Eheader=y -e frame.number -e frame.len > frame.len
# Out:
# tshark: The file "allatttack_freebsd_tcpdump.pcap" appears to have been cut short in the middle of a packet.

# %%
import pandas as pd

# %%
df=pd.read_table("frame.len")
df.head()
# Out:
#    frame.number  frame.len
# 0             1         60
# 1             2         42
# 2             3        106
# 3             4        106
# 4             5         60

# %%
df["frame.len"].describe()
# Out:
# count    850613.000000
# mean        101.543780
# std         130.983418
# min          42.000000
# 25%          60.000000
# 50%          62.000000
# 75%          66.000000
# max        1514.000000
# dtype: float64

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df["frame.len"].plot(style=".", alpha=0.2,figsize=(10,6))
title("Frame length AllAttack Freebsd")
ylabel("bytes")
xlabel("frame number")
