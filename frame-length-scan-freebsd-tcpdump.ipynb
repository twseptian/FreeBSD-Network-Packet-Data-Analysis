# %%
# !tshark -n -r scan_freebsd_tcpdump.pcap -T fields -Eheader=y -e frame.number -e frame.len > frame.len

# %%
import pandas as pd

# %%
df=pd.read_table("frame.len")
df.head()
# Out:
#    frame.number  frame.len
# 0             1         60
# 1             2         42
# 2             3         62
# 3             4         60
# 4             5         62

# %%
df["frame.len"].describe()
# Out:
# count    1063383.000000
# mean         127.881517
# std          149.960713
# min           42.000000
# 25%           60.000000
# 50%           60.000000
# 75%           62.000000
# max         1514.000000
# dtype: float64

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df["frame.len"].plot(style=".", alpha=0.2,figsize=(10,6))
title("Frame length Scanning Freebsd")
ylabel("bytes")
xlabel("frame number")
